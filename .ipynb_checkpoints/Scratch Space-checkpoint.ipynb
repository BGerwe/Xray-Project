# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import time
import re

# %%
freq=0.5
Zparams=[63.97,47.43,0.0066108,.932]
R1=Zparams[0]
R2=Zparams[1]
Q=Zparams[2]
a=Zparams[3]

size=(6,4)

t=np.arange(0,20,.001)
V1=np.sin(freq*2*np.pi*t+np.pi*.75)
I1=.6*np.sin(freq*2*np.pi*t+np.pi*(.75+1/4)) 
X1=.2*np.sin(freq*2*np.pi*t+np.pi*1.75)

V=np.sin(freq*2*np.pi*t)
I=.6*np.sin(freq*2*np.pi*t+np.pi/4) 
X=.2*np.sin(freq*2*np.pi*t+np.pi)

fig1, f1_ax1=plt.subplots(ncols=1,nrows=1,figsize=size)
f1_ax1.plot(t,V1,'-x')
f1_ax1.set(xlabel='Time / s', ylabel=r'Amplitude / a.u.')
# fig1.savefig('Data Flow Figure1 V.png',dpi=500,bbox_inches='tight')

fig2, f2_ax1=plt.subplots(ncols=1,nrows=1,figsize=size)
f2_ax1.plot(t,V,'-x')
f2_ax1.set(xlabel='Time / s', ylabel=r'Amplitude / a.u.')            
# fig2.savefig('Data Flow Figure2.png',dpi=500,bbox_inches='tight')

fig3, f3_ax1=plt.subplots(ncols=1,nrows=1,figsize=size)
f3_ax1.plot(t[:2001],V[:2001],'-x')
f3_ax1.set(xlabel='Time / s', ylabel=r'Amplitude / a.u.')
fig3.savefig('Data Flow Figure3.png',dpi=500,bbox_inches='tight')

fig4, f4_ax1=plt.subplots(ncols=1,nrows=1,figsize=size)
f4_ax1.plot(t[:2001:40],V[:2001:40],'-x')
f4_ax1.set(xlabel='Time / s', ylabel=r'Amplitude / a.u.')
fig4.savefig('Data Flow Figure4.png',dpi=500,bbox_inches='tight')
