# %%
import numpy as np
import pandas as pd
import re, os, path, csv
import glob

import h5py
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, r'C:\Users\shadd\OneDrive\Documents\Python\frxas.py')

from frxas import time_domain, models, hdf5_io
# %reload_ext autoreload
# %autoreload 2

# %%
def sort_func(all_files):
    return int(all_files.split('\\E')[-1][:-4])

# %%
direc = r'E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\'
freq_in = 0.5
ROhm = 27.89

Ir_avgs = []
for E in range(1, 181):
    ti, V, J, Ir, Io, If, Eta = [], [], [], [], [], [], []
    Ir_adj, J_adj, V_adj, Eta_adj = [], [], [], []
    Ir_adj_fit, J_adj_fit, V_adj_fit, Eta_adj_fit = [], [], [], []
    match_str = f'E{E}.txt'
    print(direc+match_str)
    ti, V, J, Ir, Io, If = time_domain.extract_data(direc, match_str,skip_head=0, sort_func=sort_func, end=2, xray_disp=False, xray_raw=True)
    ti = ti[::50]
    # Reversing V and J because the BioLogic SP-150 inverts these
    V = -V[::50]
    J = -J[::50]
    Ir = Ir[::50]
    Io = Io[::50]
    If = If[::50]
    print('Finished reading data')
    b = 0.1 * freq_in * (ti[-1]+ti[1])
    Eta = V - J * ROhm 
    print('Phase align Ir')
    Ir_adj, Ir_adj_fit = time_domain.phase_align(ti, Eta, Ir, freq_in, b, phase=-90)
    print('Phase align J')
    J_adj, J_adj_fit = time_domain.phase_align(ti, Eta, J, freq_in, b, phase=-90)
    print('Phase align V')
    V_adj, V_adj_fit = time_domain.phase_align(ti, Eta, V, freq_in, b, phase=-90)
    print('Phase align Eta')
    Eta_adj, Eta_adj_fit = time_domain.phase_align(ti, Eta, Eta, freq_in, b, phase=-90)

    print('Save fits')
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\{str(match_str[:-4])}_EtaAlign_Ir', Ir_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\{str(match_str[:-4])}_EtaAlign_J', J_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\{str(match_str[:-4])}_EtaAlign_V', V_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\{str(match_str[:-4])}_EtaAlign_Eta', Eta_adj_fit)
    Ir_avgs.append(np.mean(If/Io))

Elist_fname = f'C:\\Users\\shadd\\OneDrive\\Documents\\Python\\Xray-project\\Dynamic XAS\\Energy List.txt'
energies = np.genfromtxt(Elist_fname)

# f0 = open('..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\Energies_Iravgs.csv', 'w+', newline='')
# f = csv.writer(f0)
# f.writerow(['File', 'Energy (eV)', 'Ir Avg'])
# for i, (energy, Ir_avg) in enumerate(zip(energies, Ir_avgs)):
#     f.writerow([i+1, energy, Ir_avg])
#     print(f'E{i+1}, {energy}, {Ir_avg}')
# f0.close()
# Out:
# E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\E1.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\E2.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\E3.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\E4.txt
# Finished reading data
# Phase align Ir
# Phase align J
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-129ce87fdf4c> in <module>
#      24     Ir_adj, Ir_adj_fit = time_domain.phase_align(ti, Eta, Ir, freq_in, b, phase=-90)
#      25     print('Phase align J')
# ---> 26     J_adj, J_adj_fit = time_domain.phase_align(ti, Eta, J, freq_in, b, phase=-90)
#      27     print('Phase align V')
#      28     V_adj, V_adj_fit = time_domain.phase_align(ti, Eta, V, freq_in, b, phase=-90)
#
# ~\OneDrive\Documents\Python\frxas.py\frxas\time_domain.py in phase_align(***failed resolving arguments***)
#     231     sig_fit = fit_windowed_fft(freqs, sig_fft, freq_in, window_param,
#     232                                harmonics=harmonics, fit_kws=fit_kws,
# --> 233                                weights=weights)
#     234     del ref_fft, sig_fft
#     235
#
# ~\OneDrive\Documents\Python\frxas.py\frxas\time_domain.py in fit_windowed_fft(frequencies, signal_fft, freq_in, window_param, harmonics, fit_kws, weights)
#     177     model_fit = model.fit(signal_fft, params=params, frequencies=frequencies,
#     178                           freq_in=freq_in, window_param=window_param,
# --> 179                           weights=weights)
#     180     return model_fit
#     181
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, **kwargs)
#    1011                              nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1012                              max_nfev=max_nfev, **fit_kws)
# -> 1013         output.fit(data=data, weights=weights)
#    1014         output.components = self.components
#    1015         return output
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1364         self.userkws.update(kwargs)
#    1365         self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1366         _ret = self.minimize(method=self.method)
#    1367
#    1368         for attr in dir(_ret):
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2283                         val.lower().startswith(user_method)):
#    2284                     kwargs['method'] = val
# -> 2285         return function(**kwargs)
#    2286
#    2287
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, max_nfev, **kws)
#    1644         result.call_kws = lskws
#    1645         try:
# -> 1646             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1647         except AbortFitException:
#    1648             pass
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     421             maxfev = 200*(n + 1)
#     422         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 423                                  gtol, maxfev, epsfcn, factor, diag)
#     424     else:
#     425         if col_deriv:
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     574             raise AbortFitException("fit aborted: too many function evaluations (%d)." % self.max_nfev)
#     575
# --> 576         out = self.userfcn(params, *self.userargs, **self.userkws)
#     577
#     578         if callable(self.iter_cb):
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\model.py in _residual(self, params, data, weights, **kwargs)
#     746
#     747         """
# --> 748         model = self.eval(params, **kwargs)
#     749         if self.nan_policy == 'raise' and not np.all(np.isfinite(model)):
#     750             msg = ('The model function generated NaN values and the fit '
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#    1124     def eval(self, params=None, **kwargs):
#    1125         """Evaluate model function for composite model."""
# -> 1126         return self.op(self.left.eval(params=params, **kwargs),
#    1127                        self.right.eval(params=params, **kwargs))
#    1128
#
# ~\Anaconda3\envs\UW_research\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     834
#     835         """
# --> 836         return self.func(**self.make_funcargs(params, kwargs))
#     837
#     838     @property
#
# ~\OneDrive\Documents\Python\frxas.py\frxas\time_domain.py in fft_shape(frequencies, freq_in, window_param, harmonic, re_comp, im_comp)
#     514
#     515     g_pk = gauss_fft(f, f_tilde, b, k)
# --> 516     g_nk = gauss_fft(f, f_tilde, b, -k)
#     517     d_pk = dawson_fft(f, f_tilde, b, k)
#     518     d_nk = dawson_fft(f, f_tilde, b, -k)
#
# ~\OneDrive\Documents\Python\frxas.py\frxas\time_domain.py in gauss_fft(frequencies, freq_in, window_param, harmonic)
#     360     x = ((w - k * w_tilde) * np.pi * b) / w_tilde
#     361
# --> 362     g_k = (b * np.sqrt(np.pi) / (dt * Ns * w_tilde)) * np.exp(-x**2)
#     363
#     364     return g_k
#
# KeyboardInterrupt:

# %%
Elist_fname = f'C:\\Users\\shadd\\OneDrive\\Documents\\Python\\Xray-project\\Dynamic XAS\\Energy List.txt'
energies = np.genfromtxt(Elist_fname)

f0 = open('..\\Feb2018 Data Fits\\Energy Spectrum_0.5Hz\\Energies_Iravgs.csv', 'w+', newline='')
f = csv.writer(f0)
f.writerow(['File', 'Energy (eV)', 'Ir Avg'])
for i, (energy, Ir_avg) in enumerate(zip(energies, Ir_avgs)):
    f.writerow([i+1, energy, Ir_avg])
    print(f'E{i+1}, {energy}, {Ir_avg}')
f0.close()
# Out:
# E1, 7600.067, 1.376746862041467
# E2, 7610.641, 1.5333181506478823
# E3, 7624.556, 1.5811253967931265
# E4, 7637.2, 1.6308285419794588
# E5, 7649.699, 1.624436477663284
# E6, 7662.199, 1.6256657683841618
# E7, 7674.733, 1.7408324006379772
# E8, 7687.331, 1.6368161795486451
# E9, 7700.01, 1.642090565961313
# E10, 7700.388, 1.645405147587245
# E11, 7700.719, 1.64987663283183
# E12, 7701.071, 1.6492493638561447
# E13, 7701.434, 1.6451397733253308
# E14, 7701.798, 1.6505838780508841
# E15, 7702.155, 1.6503566103969904
# E16, 7702.515, 1.6475752832746533
# E17, 7702.879, 1.6454181713024123
# E18, 7703.242, 1.6455671863584198
# E19, 7703.6, 1.6449311081667768
# E20, 7703.961, 1.6478352706974968
# E21, 7704.325, 1.6521218949637424
# E22, 7704.687, 1.6518897019053123
# E23, 7705.02, 1.6504353359257826
# E24, 7705.381, 1.648534085111711
# E25, 7705.749, 1.650749903448115
\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\'
freq_in = 1
ROhm = 27.89

Ir_avgs = []
for E in range(1, 181):

    ti, V, J, Ir, Io, If, Eta = [], [], [], [], [], [], []
    Ir_adj, J_adj, V_adj, Eta_adj = [], [], [], []
    Ir_adj_fit, J_adj_fit, V_adj_fit, Eta_adj_fit = [], [], [], []
    match_str = f'E{E}.txt'
    print(direc+match_str)
    ti, V, J, Ir, Io, If = time_domain.extract_data(direc, match_str,skip_head=0, sort_func=sort_func, end=2, xray_disp=False, xray_raw=True)
    ti = ti[::50]
    # Reversing V and J because the BioLogic SP-150 inverts these
    V = -V[::50]
    J = -J[::50]
    Ir = Ir[::50]
    Io = Io[::50]
    If = If[::50]
    print('Finished reading data', ti.size)
    b = 0.1 * freq_in * (ti[-1]+ti[1])
    Eta = V - J * ROhm 
    print('Phase align Ir')
    Ir_adj, Ir_adj_fit = time_domain.phase_align(ti, Eta, Ir, freq_in, b, phase=-90)
    print('Phase align J')
    J_adj, J_adj_fit = time_domain.phase_align(ti, Eta, J, freq_in, b, phase=-90)
    print('Phase align V')
    V_adj, V_adj_fit = time_domain.phase_align(ti, Eta, V, freq_in, b, phase=-90)
    print('Phase align Eta')
    Eta_adj, Eta_adj_fit = time_domain.phase_align(ti, Eta, Eta, freq_in, b, phase=-90)

    print('Save fits')
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_1Hz\\{str(match_str[:-4])}_EtaAlign_Ir', Ir_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_1Hz\\{str(match_str[:-4])}_EtaAlign_J', J_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_1Hz\\{str(match_str[:-4])}_EtaAlign_V', V_adj_fit)
    hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_1Hz\\{str(match_str[:-4])}_EtaAlign_Eta', Eta_adj_fit)
    Ir_avgs.append(np.mean(If/Io))

Elist_fname = f'C:\\Users\\shadd\\OneDrive\\Documents\\Python\\Xray-project\\Dynamic XAS\\Energy List.txt'
energies = np.genfromtxt(Elist_fname)

f0 = open('..\\Feb2018 Data Fits\\Energy Spectrum_1Hz\\Energies_Iravgs.csv', 'w+', newline='')
f = csv.writer(f0)
f.writerow(['File', 'Energy (eV)', 'Ir Avg'])
for i, (energy, Ir_avg) in enumerate(zip(energies, Ir_avgs)):
    f.writerow([i+1, energy, Ir_avg])
    print(f'E{i+1}, {energy}, {Ir_avg}')
f0.close()
# Out:
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E1.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E2.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E3.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E4.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E5.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E6.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E7.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E8.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E9.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E10.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E11.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E12.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E13.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E14.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E15.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E16.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E17.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E18.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E19.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E20.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E21.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E22.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E23.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E24.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E25.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E26.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E27.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E28.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E29.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E30.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E31.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E32.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E33.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E34.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E35.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E36.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E37.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E38.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E39.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E40.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E41.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E42.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E43.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E44.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E45.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E46.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E47.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E48.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E49.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E50.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E51.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E52.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E53.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E54.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E55.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E56.txt
# Finished reading data 49000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E57.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E58.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E59.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E60.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E61.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E62.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E63.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E64.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E65.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E66.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E67.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E68.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E69.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E70.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E71.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E72.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E73.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E74.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E75.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E76.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E77.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E78.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\E79.txt
# Finished reading data 61000
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_1Hz\\Txt Files\\
# E137, 7734.214, 3.0310211048940565
# E138, 7734.976, 3.022778486133607
# E139, 7735.775, 3.0141467660594716
# E140, 7736.539, 3.001244123377688
# E141, 7737.309, 2.9699588658945006
# E142, 7738.078, 2.975622569526009
# E143, 7738.844, 2.961581551088655
# E144, 7739.616, 2.9591456696160763
# E145, 7740.388, 2.9369486126143527
# E146, 7741.161, 2.9156400023515627
# E147, 7741.952, 2.8988418692083524
# E148, 7744.452, 2.82466565700664
# E149, 7746.969, 2.760255168249879
# E150, 7749.453, 2.6915895883316003
# E151, 7751.935, 2.658743586939067
# E152, 7754.455, 2.617416671574734
# E153, 7756.949, 2.6105542244039395
# E154, 7759.43, 2.6274905337734906
# E155, 7761.947, 2.6637972954732447
# E156, 7764.468, 2.67328949191534
# E157, 7766.965, 2.6930233166494406
# E158, 7769.462, 2.733112433502271
# E159, 7771.987, 2.760785780750527
# E160, 7774.488, 2.7823548391927204
# E161, 7776.997, 2.817451879432683
# E162, 7780.562, 2.8132319975988618
# E163, 7784.149, 2.832018496631315
# E164, 7787.693, 2.828677155985941
# E165, 7791.282, 2.846093230421327
# E166, 7794.862, 2.800681235317694
# E167, 7798.436, 2.7757076469402557
# E168, 7802.015, 2.7751808162270133
# E169, 7805.614, 2.77221882379745
# E170, 7809.204, 2.7573106500590163
# E171, 7812.809, 2.7459832652562515
# E172, 7816.381, 2.74150321712432
# E173, 7819.994, 2.7273244401101833
# E174, 7823.605, 2.7143959632544785
# E175, 7827.223, 2.705887424281079
# E176, 7830.814, 2.6901553461179732
# E177, 7834.438, 2.6887033108999905
# E178, 7838.06, 2.6991494154565956
# E179, 7841.69, 2.6879387370142283
# E180, 7845.32, 2.6767882511655294

# %%
np.isnan(Ir).any()
# Out:
# False

# %%
direc = r'E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\'
freq_in = 5
ROhm = 27.89
Ir_avgs = []
bads = []
for E in range(1, 181):
    try:
        ti, V, J, Ir, Io, If, Eta = [], [], [], [], [], [], []
        Ir_adj, J_adj, V_adj, Eta_adj = [], [], [], []
        Ir_adj_fit, J_adj_fit, V_adj_fit, Eta_adj_fit = [], [], [], []
        match_str = f'E{E}.txt'
        print(direc+match_str)
        ti, V, J, Ir, Io, If = time_domain.extract_data(direc, match_str,skip_head=0, sort_func=sort_func, end=2, xray_disp=False, xray_raw=True)
        ti = ti[::50]
        # Reversing V and J because the BioLogic SP-150 inverts these
        V = -V[::50]
        J = -J[::50]
        Ir = Ir[::50]
        Io = Io[::50]
        If = If[::50]
        print('Finished reading data')
        b = 0.1 * freq_in * (ti[-1]+ti[1])
        Eta = V -J * ROhm 
        print('Phase align Ir')
        Ir_adj, Ir_adj_fit = time_domain.phase_align(ti, Eta, Ir, freq_in, b, phase=-90)
        print('Phase align J')
        J_adj, J_adj_fit = time_domain.phase_align(ti, Eta, J, freq_in, b, phase=-90)
        print('Phase align V')
        V_adj, V_adj_fit = time_domain.phase_align(ti, Eta, V, freq_in, b, phase=-90)
        print('Phase align Eta')
        Eta_adj, Eta_adj_fit = time_domain.phase_align(ti, Eta, Eta, freq_in, b, phase=-90)

        print('Save fits')
        hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_5Hz\\{str(match_str[:-4])}_EtaAlign_Ir', Ir_adj_fit)
        hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_5Hz\\{str(match_str[:-4])}_EtaAlign_J', J_adj_fit)
        hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_5Hz\\{str(match_str[:-4])}_EtaAlign_V', V_adj_fit)
        hdf5_io.save_time_domain_fit(f'..\\Feb2018 Data Fits\\Energy Spectrum_5Hz\\{str(match_str[:-4])}_EtaAlign_Eta', Eta_adj_fit)
        Ir_avgs.append(np.mean(If/Io))
    except:
        print(f'Couldn\'t analyze {E}')
        bads.append(E)

Elist_fname = f'C:\\Users\\shadd\\OneDrive\\Documents\\Python\\Xray-project\\Dynamic XAS\\Energy List.txt'
energies = np.genfromtxt(Elist_fname)

f0 = open('..\\Feb2018 Data Fits\\Energy Spectrum_5Hz\\Energies_Iravgs.csv', 'w+', newline='')
f = csv.writer(f0)
f.writerow(['File', 'Energy (eV)', 'Ir Avg'])
for i, (energy, Ir_avg) in enumerate(zip(energies, Ir_avgs)):
    if i+1 in bads:
        continue
    f.writerow([i+1, energy, Ir_avg])
    print(f'E{i+1}, {energy}, {Ir_avg}')
f0.close()
# Out:
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E1.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E2.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E3.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E4.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E5.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E6.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E7.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E8.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E9.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E10.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E11.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E12.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E13.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E14.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E15.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E16.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E17.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E18.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E19.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E20.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E21.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E22.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E23.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E24.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E25.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E26.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E27.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E28.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E29.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E30.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E31.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E32.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E33.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E34.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E35.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E36.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E37.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E38.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E39.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E40.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E41.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E42.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E43.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E44.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E45.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E46.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E47.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E48.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E49.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E50.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E51.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E52.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E53.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E54.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E55.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E56.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E57.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E58.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E59.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E60.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E61.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E62.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E63.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E64.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E65.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E66.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E67.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E68.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E69.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E70.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E71.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E72.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E73.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E74.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E75.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E76.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E77.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E78.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E79.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E80.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E81.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E82.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E83.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E84.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E85.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E86.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E87.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E88.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E89.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E90.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E91.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E92.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E93.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E94.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E95.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E96.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E97.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E98.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E99.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E100.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E101.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E102.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E103.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E104.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E105.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E106.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E107.txt
# Finished reading data
# Phase align Ir
# Couldn't analyze 107
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E108.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E109.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E110.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E111.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E112.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E113.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E114.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E115.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E116.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E117.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E118.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E119.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E120.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E121.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E122.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E123.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E124.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E125.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E126.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E127.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E128.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E129.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E130.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E131.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E132.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E133.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E134.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E135.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E136.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E137.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E138.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E139.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E140.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E141.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E142.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E143.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E144.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E145.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E146.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E147.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E148.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E149.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E150.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E151.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E152.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E153.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E154.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E155.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E156.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E157.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E158.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E159.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E160.txt
# Finished reading data
# Phase align Ir
# Couldn't analyze 160
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E161.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E162.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E163.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E164.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E165.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E166.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E167.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E168.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E169.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E170.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E171.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E172.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E173.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E174.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E175.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E176.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E177.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E178.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_5Hz\\Redo Txt Files\\E179.txt
# Finished reading data
# Phase align Ir
# Phase align J
# Phase align V
# Phase align Eta
# Save fits
# D:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum
# E159, 7771.987, 2.813752398441598
# E161, 7776.997, 2.832962287712628
# E162, 7780.562, 2.7994108143680823
# E163, 7784.149, 2.8110883061014045
# E164, 7787.693, 2.8097480453870536
# E165, 7791.282, 2.8061625539069235
# E166, 7794.862, 2.7883037380908338
# E167, 7798.436, 2.765908878144763
# E168, 7802.015, 2.754000720404798
# E169, 7805.614, 2.75621405005963
# E170, 7809.204, 2.7399208452779593
# E171, 7812.809, 2.732214890915637
# E172, 7816.381, 2.708240714305716
# E173, 7819.994, 2.707471348574662
# E174, 7823.605, 2.694691949546176
# E175, 7827.223, 2.6977442870724375
# E176, 7830.814, 2.696119073406325
# E177, 7834.438, 2.6852790852488475
# E178, 7838.06, 2.697443362860861

# %%
direc = r'E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\'
E = 82
freq_in = 0.5
ROhm = 27.89
Ir_avgs = []
bads = []

ti, V, J, Ir, Io, If, Eta = [], [], [], [], [], [], []
match_str = f'E{E}.txt'
print(direc+match_str)
ti, V, J, Ir, Io, If = time_domain.extract_data(direc, match_str,skip_head=0, sort_func=sort_func, end=2, xray_disp=False, xray_raw=True)
ti = ti[::50]
# Reversing V and J because the BioLogic SP-150 inverts these
V = -V[::50]
J = -J[::50]
Ir = Ir[::50]
Io = Io[::50]
If = If[::50]
Eta = V -J * ROhm
# Out:
# E:\\UW Research\\fr-XAS Feb 2018\\Energy Spectrum_0.5Hz\\Txt Files\\E82.txt

# %%
_, ax = plt.subplots()
ax.plot(ti, V, label='V')
ax.plot(ti, Ir, label='Ir')
ax.plot(ti, J, label='J')
ax.plot(ti, Eta, label='Eta')
ax.set_xlim(0,5)
ax.legend(loc='upper right')
plt.show()

# %%
_, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10,10))
step = 2000
for i, (ti, V, J, Ir, Ir_fit) in enumerate(zip(tis, Vs, Js, Ir_adjs, Ir_fits)):
    ax1.plot(ti[1:Ns_wfm:step], Ir[1:Ns_wfm:step].real-np.mean(Ir[:Ns_wfm].real), label=str(i))
    ax2.plot(ti[1:Ns_wfm:step], V[1:Ns_wfm:step].real)
    frequencies = Ir_fit.userkws['frequencies']
# for i, (ti, V, J, Ir, Ir_fit) in enumerate(zip(tis, Vs, Js, Ir_adjs, Ir_fits)):
#     Ir_synth = np.fft.ifft(np.fft.ifftshift(Ir_fit.eval()*(ti.size*np.pi)))
#     ax1.plot(ti[1:Ns_wfm:step], Ir_synth[1:Ns_wfm:step].real,'--')
ax1.set_xlim(0,1/freq_in)
ax2.set_xlim(0,1/freq_in)
ax1.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8639c9171403> in <module>
#       1 _, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10,10))
#       2 step = 2000
# ----> 3 for i, (ti, V, J, Ir, Ir_fit) in enumerate(zip(tis, Vs, Js, Ir_adjs, Ir_fits)):
#       4     ax1.plot(ti[1:Ns_wfm:step], Ir[1:Ns_wfm:step].real-np.mean(Ir[:Ns_wfm].real), label=str(i))
#       5     ax2.plot(ti[1:Ns_wfm:step], V[1:Ns_wfm:step].real)
#
# NameError: name 'tis' is not defined
