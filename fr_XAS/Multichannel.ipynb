# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd

# %%
direc = r'\November 2019 Test Data'
print(os.getcwd())
all_files=glob.glob(os.getcwd() + direc + '\*.txt')
print(os.getcwd()+direc)
all_files.sort()
# Out:
# C:\Users\shadd\OneDrive\Documents\Python\Xray-project\fr_XAS
# C:\Users\shadd\OneDrive\Documents\Python\Xray-project\fr_XAS\November 2019 Test Data

# %%
def GetLineScanData(direc):
    all_files=glob.glob(direc + '\*Xpress.txt')
    all_files.sort()
    
    for file in all_files:
        dat = pd.read_csv(file, delimiter='\t', header=0)
#         if i == 1:
#             datSum = pd.read_csv(file, delimiter='\t', header=0)
#         else:
#             dat1=np.array(datSum)
#             dat2=np.array(pd.read_csv(file, delimiter='\t', header=0))
    return dat

# %%
# GetLineScanData(r'G:\My Drive\UW Research\fr-XAS November 2019\Data\TPB2\100% O2\fr-XAS\5 Hz\626 mV')
GetLineScanData(r'C:\Users\shadd\OneDrive\Documents\Python\Xray-project\fr_XAS\November 2019 Test Data')
# Out:
#        Time  Position        I0  ROI1_Ch1  ROI1_Ch2  ROI1_Ch3  ROI1_Ch4  \
# 0      0.00   1190.01  6304.914   639.722   638.652   757.614   788.622
# 1      0.01   1190.02  6325.914   625.722   652.652   712.614   755.622
# 2      0.02   1190.03  6281.914   584.722   658.652   731.614   725.622
# 3      0.03   1190.04  6305.914   607.722   598.652   722.614   826.622
# 4      0.04   1190.05  6277.914   534.722   642.652   701.614   765.622
# ...     ...       ...       ...       ...       ...       ...       ...
# 9995  99.95   1289.96  6298.914    -0.278   654.652   700.614   703.622
# 9996  99.96   1289.97  6240.914    -0.278   675.652   699.614   734.622
# 9997  99.97   1289.98  6325.914    -0.278   664.652   709.614   750.622
# 9998  99.98   1289.99  6376.914    -0.278   609.652   709.614    -0.378
# 9999  99.99   1290.00  6283.914    -0.278    -0.348    -0.386    -0.378
#
#       ROI1_Ch5  ROI1_Ch6  ROI1_Ch7  ...   ICR_Ch3  ICR_Ch4   ICR_Ch5  \
# 0       419.81    403.81   465.804  ...  7394.452  7366.44  7097.628
# 1       403.81    396.81   407.804  ...  7331.452  7332.44  7177.628
# 2       401.81    412.81   429.804  ...  7285.452  7280.44  7151.628
# 3       414.81    373.81   428.804  ...  7152.452  7346.44  7187.628
# 4       384.81    343.81   429.804  ...  7275.452  7296.44  7148.628
# ...        ...       ...       ...  ...       ...      ...       ...
# 9995    386.81    395.81    -0.196  ...  7482.452    -3.56  6937.628
# 9996    415.81    377.81    -0.196  ...  7216.452    -3.56  6900.628
# 9997    401.81     -0.19    -0.196  ...  7325.452    -3.56  6889.628
# 9998    410.81     -0.19    -0.196  ...  7349.452    -3.56  6972.628
# 9999    406.81     -0.19    -0.196  ...  7298.452    -3.56  6910.628
#
#        ICR_Ch6   ICR_Ch7   ICR_Ch8  ROI1sum/I0  Time.1   Current   Voltage
# 0     6499.064  6797.764  7691.146    0.724006    0.00 -0.003064 -0.005996
# 1     6464.064  6754.764  7751.146    0.700420    0.01  0.013507 -0.001746
# 2     6452.064  6639.764  7709.146    0.699595    0.02  0.038519  0.004474
# 3     6434.064  6761.764  7762.146    0.699629    0.03  0.042959  0.011287
# 4     6423.064  6713.764  7756.146    0.684749    0.04  0.059967  0.019945
# ...        ...       ...       ...         ...     ...       ...       ...
# 9995  6218.064    -3.236    -3.854    0.450998   99.95 -0.030327 -0.057129
# 9996  6342.064    -3.236    -3.854    0.465124   99.96 -0.010505 -0.049159
# 9997    -2.936    -3.236    -3.854    0.399278   99.97 -0.001970 -0.041689
# 9998    -2.936    -3.236    -3.854    0.271103   99.98  0.013225 -0.033094
# 9999    -2.936    -3.236    -3.854    0.064418   99.99  0.027513 -0.024530
#
# [10000 rows x 23 columns]

# %%
filename=all_files[0]

data=pd.read_csv(filename,delimiter= '\t', header=0)

# %%
Ir=np.array(data['ROI1sum/I0'])
t=np.array(data['Time'])
I=np.array(data['Current'])
V=np.array(data['Voltage'])
Pos=np.array(data['Position'])

# %%
plt.subplots_adjust(hspace=.25)
fig, (ax1,ax2) = plt.subplots(ncols=1,nrows=2,figsize=(6,6))

ax1.plot(Pos,Ir)
ax1.set_xlim(1229.5,1245.5)
ax1.set_ylim(.2,.8)
ax1.set_ylabel('X-Ray Abs.')

ax2.plot(Pos,I)#,Pos,I)
ax2.set_xlim(1229.5,1245.5)
ax2.set_xlabel(r'Position $\mu m$')
ax2.set_ylabel('Voltage / V')
# fig.savefig('Raw Abs.png', dpi=300 , bbox_inches='tight')

fig2, (ax3, ax4) = plt.subplots(ncols=1,nrows=2,figsize=(6,6))
ax3.plot(Pos, Ir)
ax3.set_xlim(1240,1260)
ax3.set_ylim(.6,.8)
ax3.set_ylabel('X-Ray Abs.')

ax4.plot(Pos, V)
ax4.set_xlim(1240,1260)
ax4.set_xlabel(r'Position $\mu m$')
ax4.set_ylabel('Voltage / V')
# fig2.savefig('Raw Abs Zoom.png', dpi=300 , bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Voltage / V')

# %%
direc=r'G:\My Drive\UW Research\fr-XAS November 2019\Data\DPB2\700C_100%O2\fr-XAS\10 Hz\213 mV'
direc=r'C:\Users\shadd\OneDrive\Documents\Python\Xray-project\fr_XAS\November 2019 Test Data\191101_Amezawa\fr_XAS\TPB2\100% O2\fr-XAS\5 Hz\119 mV'

all_files = glob.glob(direc + '\*Xpress.txt')
all_files.sort()


fig, (ax1,ax2,ax3) = plt.subplots(ncols=1,nrows=3,figsize=(10,10))

Iravg = []
Iavg = []
Vavg = []


for i in range(len(all_files)):
    dat = pd.read_csv(all_files[i], delimiter='\t', header=0)
    
    
    
    Ir = np.array(dat['ROI1sum/I0'])
    t = np.array(dat['Time'])
    I = np.array(dat['Current'])
    V = np.array(dat['Voltage'])
    Pos = np.array(dat['Position'])
    
    if i == 0:
        Iravg = Ir
        Iavg = I
        Vavg = V
    else:
        Iravg = Iravg+Ir
        Iavg = Iavg+I
        Vavg = Vavg+V
        
    Iravg = Iravg/len(all_files)
    Iavg = Iavg/len(all_files)
    Vavg = Vavg/len(all_files)
    
    t_str = 56
    t_end = 58
    ax1.plot(t,Ir)
    ax1.set_xlim(t_str,t_end)
    ax2.plot(t,V)
    ax2.set_xlim(t_str,t_end)
    ax3.plot(t,I)
    ax3.set_xlim(t_str,t_end)
    
    
plt.show()

# %%
tstart=3.2
tend=3.8

fig, (ax1,ax2,ax3) = plt.subplots(ncols=1,nrows=3,figsize=(10,10))
ax1.plot(t,Iravg)
ax1.set_xlim(tstart,tend)
# ax1.set_ylim(.08,.1)


ax2.plot(t,Vavg)
ax2.set_xlim(tstart,tend)
# ax2.set_ylim(-.2,.2)


ax3.plot(t,Iavg)
ax3.set_xlim(tstart,tend)
# ax3.set_ylim(-.2,.2)
# Out:
# (3.2, 3.8)

# %%
pstart=1238
pend=1242

fig, (ax1,ax2,ax3) = plt.subplots(ncols=1,nrows=3,figsize=(10,10))
ax1.plot(Pos,Iravg)
ax1.set_xlim(pstart,pend)
ax1.set_ylim(.30,.35)


ax2.plot(Pos,Vavg,'x')
ax2.set_xlim(pstart,pend)
ax2.set_ylim(-.2,.2)


ax3.plot(Pos,Iavg)
ax3.set_xlim(pstart,pend)
# ax3.set_ylim(-.2,.2)
# Out:
# (1238, 1242)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1,nrows=2,figsize=(12,6))

ax1.plot(Pos[Pos>1240]-1240,Ir[Pos>1240]-np.mean(Ir[Pos>1240]))
ax1.set_xlim(0,40)
ax1.set_ylim(-.05,.05)
ax1.set_ylabel('X-Ray Abs.')
ax1.set_xlabel('Position $\mu m$')
plt.subplots_adjust(hspace=.25)

ax2.plot(t[Pos>1240]-t[Pos>1240][0],Ir[Pos>1240]-np.mean(Ir[Pos>1240]))
ax2.set_xlim(0,40/v)
ax2.set_ylim(-.05,.05)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('X-Ray Abs.')
# Out:
# Text(0, 0.5, 'X-Ray Abs.')

# %%
np.array(t[Pos>1240])[0]
# Out:
# 50.0

# %%
v=(Pos[1]-Pos[0])/t[1]
# Out:
# 0.9999999999990905
